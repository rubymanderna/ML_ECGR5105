# %% [markdown]
# <a href="https://colab.research.google.com/github/rubymanderna/ML_ECGR5105/blob/main/Final_project/Data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import librosa
import numpy as np
from tqdm import tqdm

# %%
def extract_features(file_path, sampling_rate=48000):
    try:
        y, _ = librosa.load(file_path, sr=sampling_rate)

        spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sampling_rate)[0]
        spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sampling_rate)[0]
        spectral_rolloff = librosa.feature.spectral_rolloff(y=y, sr=sampling_rate)[0]

        mfccs = librosa.feature.mfcc(y=y, sr=sampling_rate)

        chroma = librosa.feature.chroma_stft(y=y, sr=sampling_rate)

        contrast = librosa.feature.spectral_contrast(y=y, sr=sampling_rate)

        tonnetz = librosa.feature.tonnetz(y=librosa.effects.harmonic(y), sr=sampling_rate)

        rmse = librosa.feature.rms(y=y)[0]

        # Concatenate all features into a single 1D array
        all_features = [spectral_centroid.mean(), spectral_bandwidth.mean(), spectral_rolloff.mean()] + \
                        list(mfccs.mean(axis=1)) + list(chroma.mean(axis=1)) + list(contrast.mean(axis=1)) + \
                        list(tonnetz.mean(axis=1)) + [rmse.mean()]

        return all_features

    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None

# %%
csv_path = '/content/drive/MyDrive/kaggle/cv-valid-test.csv'  # Replace with your actual CSV file path
df = pd.read_csv(csv_path)

# %%
df_sampled = df.dropna(subset=['age'])
df_sampled = df_sampled.reset_index(drop=True)
df_sampled.tail()
# Out:
#            filename                                               text  \
# 1537  sample-003976                              we've got her located
# 1538  sample-003979                          she has all your features
# 1539  sample-003980                  i've got to see nicole right away
# 1540  sample-003984  but there were certain of them who took a bit ...
# 1541  sample-003989                              i'm playing for keeps
#
#       up_votes  down_votes       age gender     accent  duration
# 1537         1           0  thirties   male    england       NaN
# 1538         1           0  thirties   male        NaN       NaN
# 1539         1           0   fifties   male  australia       NaN
# 1540         2           0  thirties   male        NaN       NaN
# 1541         2           0   fifties   male  australia       NaN

# %%
features_list = []
for index, row in tqdm(df_sampled.iterrows(), total=len(df_sampled), desc="Processing files"):
    filename = row['filename']
    age = row['age']

    # Search for the corresponding .mp3 file in the folder
    mp3_path = f'/content/drive/MyDrive/kaggle/cv-valid-test/{filename}.mp3'  # Replace with your actual folder path
    if os.path.exists(mp3_path):
        # Extract features using librosa with try-except
        features = extract_features(mp3_path)
        if features is not None:
            features_list.append([filename, age] + features)
features_df = pd.DataFrame(features_list, columns=['filename', 'age', 'spectral_centroid', 'spectral_bandwidth',
                                                   'spectral_rolloff'] + [f'mfcc_{i}' for i in range(1, 21)] +
                                                  [f'chroma_{i}' for i in range(1, 13)] +
                                                  [f'contrast_{i}' for i in range(1, 8)] +
                                                  [f'tonnetz_{i}' for i in range(1, 7)] + ['rmse'])

# Save the final DataFrame to a new CSV file
output_csv_path = '/content/drive/MyDrive/kaggle/test1_extracted_features.csv'  # Replace with your desired output path
features_df.to_csv(output_csv_path, index=False)

print(f"Processed {len(features_df)} files and saved features to {output_csv_path}")
# Out:
# Processing files:   0%|          | 0/1542 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=729
#   warnings.warn(
# Processing files:   0%|          | 4/1542 [00:15<1:10:14,  2.74s/it]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=981
#   warnings.warn(
# Processing files:   1%|          | 8/1542 [00:19<35:50,  1.40s/it]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=864
#   warnings.warn(
# Processing files:   1%|          | 12/1542 [00:22<24:37,  1.04it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=711
#   warnings.warn(
# Processing files:   1%|          | 16/1542 [00:26<23:51,  1.07it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=936
#   warnings.warn(
# Processing files:   1%|▏         | 20/1542 [00:30<25:41,  1.01s/it]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=756
#   warnings.warn(
# Processing files:   1%|▏         | 23/1542 [00:32<21:13,  1.19it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=873
#   warnings.warn(
# Processing files:   2%|▏         | 35/1542 [00:44<28:12,  1.12s/it]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=891
#   warnings.warn(
# Processing files:   3%|▎         | 39/1542 [00:48<26:43,  1.07s/it]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=657
#   warnings.warn(
# Processing files:   3%|▎         | 41/1542 [00:50<24:28,  1.02it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=774
#   warnings.warn(
# Processing files:   4%|▍         | 61/1542 [01:10<25:29,  1.03s/it]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=846
#   warnings.warn(
# Processing files:   6%|▌         | 93/1542 [01:42<26:02,  1.08s/it]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=702
#   warnings.warn(
# Processing files:   7%|▋         | 106/1542 [01:56<29:36,  1.24s/it]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=837
#   warnings.warn(
# Processing files:   7%|▋         | 108/1542 [01:58<24:25,  1.02s/it]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=954
#   warnings.warn(
# Processing files:   7%|▋         | 109/1542 [01:59<22:08,  1.08it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=819
#   warnings.warn(
# Processing files:   7%|▋         | 114/1542 [02:03<20:39,  1.15it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=963
#   warnings.warn(
# Processing files:   8%|▊         | 119/1542 [02:09<26:49,  1.13s/it]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=927
#   warnings.warn(
# Processing files:   9%|▊         | 134/1542 [02:26<30:31,  1.30s/it]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=594
#   warnings.warn(
# Processing files:   9%|▉         | 138/1542 [02:30<26:41,  1.14s/it]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=531
#   warnings.warn(
# Processing files:   9%|▉         | 140/1542 [02:32<22:15,  1.05it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=801
#   warnings.warn(
# Processing files: 100%|██████████| 1542/1542 [02:44<00:00,  9.36it/s]
# Processed 152 files and saved features to /content/drive/MyDrive/kaggle/test1_extracted_features.csv
